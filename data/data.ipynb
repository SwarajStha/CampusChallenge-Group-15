# %%
import pandas as pd

daily_return_data = pd.read_csv('train_return_data_daily.csv')

# Check column names first
print("Columns:", daily_return_data.columns.tolist())

# Convert date column to datetime
daily_return_data['date'] = pd.to_datetime(daily_return_data['date'])

# Filter for 2024: 2024-07-01 to 2024-12-31
daily_return_data_filtered = daily_return_data[(daily_return_data['date'] >= '2024-07-01') & (daily_return_data['date'] <= '2024-12-31')]

daily_return_data_filtered
# Out:
# Columns: ['date', 'TICKER', 'PRC', 'RET', 'SHROUT', 'MV_USD', 'MV_USD_lag']
#                date TICKER        PRC       RET     SHROUT        MV_USD  \
# 12378    2024-07-01   JJSF  164.94000  0.015828    19408.0  3.201156e+06
# 12379    2024-07-02   JJSF  164.55000 -0.002364    19408.0  3.193586e+06
# 12380    2024-07-03   JJSF  164.82001  0.001641    19408.0  3.198827e+06
# 12381    2024-07-05   JJSF  166.09000  0.007705    19408.0  3.223475e+06
# 12382    2024-07-08   JJSF  164.63000 -0.008790    19408.0  3.195139e+06
# ...             ...    ...        ...       ...        ...           ...
# 21828561 2024-12-24   TSLA  462.28000  0.073572  3210060.0  1.483947e+09
# 21828562 2024-12-26   TSLA  454.13000 -0.017630  3210060.0  1.457785e+09
# 21828563 2024-12-27   TSLA  431.66000 -0.049479  3210060.0  1.385654e+09
# 21828564 2024-12-30   TSLA  417.41000 -0.033012  3210060.0  1.339911e+09
# 21828565 2024-12-31   TSLA  403.84000 -0.032510  3210060.0  1.296351e+09
#
# ...

# %%
import pandas as pd

cleaned_daily_data = pd.read_csv('daily_return_data_cleaned.csv')
cleaned_daily_data
# Out:
#               date TICKER     PRC       RET    SHROUT       MV_USD  \
# 0       2024-07-01      A  127.40 -0.017203  291761.0  37170351.40
# 1       2024-07-02      A  125.78 -0.010863  291761.0  36697698.58
# 2       2024-07-03      A  126.13  0.002783  291761.0  36799814.93
# 3       2024-07-05      A  126.37  0.001903  291761.0  36869837.57
# 4       2024-07-08      A  126.07 -0.002374  291761.0  36782309.27
# ...            ...    ...     ...       ...       ...          ...
# 142261  2024-12-24    ZWS   37.82  0.009072  169714.0   6418583.48
# 142262  2024-12-26    ZWS   38.05  0.006081  169714.0   6457617.70
# 142263  2024-12-27    ZWS   37.71 -0.008936  169714.0   6399914.94
# 142264  2024-12-30    ZWS   37.47 -0.006364  169714.0   6359183.58
# 142265  2024-12-31    ZWS   37.30 -0.004537  169714.0   6330332.20
#
#          MV_USD_lag
# 0       37820978.43
# 1       37170351.40
# 2       36697698.58
# 3       36799814.93
# 4       36869837.57
# ...             ...
# ...

# %%
import pandas as pd

Extracted_File = pd.read_csv('Full Extracted File (sorted).csv')
Extracted_File
# Out:
#          date_day Ticker                                              title  \
# 0      2024-07-01      A  Agilent Appoints Bret DiMarco as Chief Legal O...
# 1      2024-07-16      A  Agilent to Announce Third-Quarter Fiscal Year ...
# 2      2024-07-19      A  Weak Demand Dragged Agilent Technologies (A) i...
# 3      2024-07-22      A  Agilent (A) Boosts DCG Segment With New Proteo...
# 4      2024-07-23      A  Estimating The Fair Value Of Agilent Technolog...
# ...           ...    ...                                                ...
# 58131  2024-12-03    ZWS  Q3 Earnings Roundup: Carrier Global (NYSE:CARR...
# 58132  2024-12-04    ZWS  Zurn Elkay Water Solutions Named No. 28 of 600...
# 58133  2024-12-12    ZWS  Zurn Elkay Water price target raised to $38 fr...
# 58134  2024-12-13    ZWS  Q3 Earnings Roundup: A. O. Smith (NYSE:AOS) An...
# 58135  2024-12-24    ZWS  If EPS Growth Is Important To You, Zurn Elkay ...
#
# ...

# %%
import pandas as pd

cleaned_sentiment = pd.read_csv('signal_return_panel_cleaned(2).csv')
cleaned_sentiment
# Out:
#       Ticker signal_date  signal_score return_date       RET        PRC  \
# 0          A  2024-07-01         0.160  2024-07-02 -0.010863  125.78000
# 1          A  2024-07-16         0.135  2024-07-17 -0.018815  133.50000
# 2          A  2024-07-19        -0.415  2024-07-22  0.012445  133.42000
# 3          A  2024-07-22         0.545  2024-07-23 -0.020762  130.64999
# 4          A  2024-07-23         0.225  2024-07-24  0.026866  134.16000
# ...      ...         ...           ...         ...       ...        ...
# 57849    ZWS  2024-12-03         0.175  2024-12-04  0.011161   40.77000
# 57850    ZWS  2024-12-04         0.235  2024-12-05 -0.016924   40.08000
# 57851    ZWS  2024-12-12         0.410  2024-12-13 -0.005998   39.77000
# 57852    ZWS  2024-12-13         0.255  2024-12-16 -0.004777   39.58000
# 57853    ZWS  2024-12-24         0.485  2024-12-26  0.006081   38.05000
#
#          MV_USD_lag  days_gap
# 0      3.717035e+07         1
# 1      3.969700e+07         1
# ...

# %%
import pandas as pd

signal_return_data = pd.read_csv('signal_return_panel.csv')
signal_return_data
# Out:
#       Ticker signal_date  signal_score return_date       RET        PRC  \
# 0          A  2024-07-01         0.160  2024-07-02 -0.010863  125.78000
# 1          A  2024-07-16         0.135  2024-07-17 -0.018815  133.50000
# 2          A  2024-07-19        -0.415  2024-07-22  0.012445  133.42000
# 3          A  2024-07-22         0.545  2024-07-23 -0.020762  130.64999
# 4          A  2024-07-23         0.225  2024-07-24  0.026866  134.16000
# ...      ...         ...           ...         ...       ...        ...
# 57875    ZWS  2024-12-03         0.175  2024-12-04  0.011161   40.77000
# 57876    ZWS  2024-12-04         0.235  2024-12-05 -0.016924   40.08000
# 57877    ZWS  2024-12-12         0.410  2024-12-13 -0.005998   39.77000
# 57878    ZWS  2024-12-13         0.255  2024-12-16 -0.004777   39.58000
# 57879    ZWS  2024-12-24         0.485  2024-12-26  0.006081   38.05000
#
#          MV_USD_lag  days_gap
# 0      3.717035e+07         1
# 1      3.969700e+07         1
# ...
