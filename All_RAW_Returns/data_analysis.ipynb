# %%
import pandas as pd

returned_data = pd.read_csv('sentiments_group 15.csv')
returned_data
# Out:
#                                                     Hash  \
# 0      417780_a1b09e18286c3e77582f10e07b3dd1cf2386572...
# 1      574051_516beded712088f61296c8635a4c0bb31f76ac4...
# 2      941051_1d4c383bc62a7761f1ca432c42a84ae63696ae0...
# 3      1139270_17cdbeecb5584520d264b537e29c431d3b936f...
# 4      1209842_3eb959694fc347fa7751d02d234e3e4eaee778...
# ...                                                  ...
# 59495  586146_4244a95340713425a33e5abb07c600ae3f7c197...
# 59496  1307797_74215fe50a22eeda1d04d1699c6460cbc04049...
# 59497  1013113_31e3bcd33830f2ea473005cf0cbf9911af9751...
# 59498  941020_8f05558d998d683e1cb81f9bc01ee9e6a3dafbb...
# 59499  758883_016387697597783f2e9a67797cc1cc0fc5e63ac...
#
#                                                sentiment  \
# 0      <think>\n\n</think>\n\nHeadline: "Amazon unvei...
# 1      <think>\n\n</think>\n\nHeadline: 'Microsoft ac...
# 2      <think>\n\n</think>\n\nHeadline: "Amazon annou...
# ...

# %%
import pandas as pd

extracted_data = pd.read_csv('Extracted Files/Extracted_file (7).csv')
extracted_data
# Out:
#          date_day Ticker                                              title  \
# 0      2024-07-01    BDX  Boing! 7 Undervalued Stocks That Could Surpris...
# 1      2024-07-01   CELH                      \nJon Quast  |  Jul 1, 2024\n
# 2      2024-07-01    EME  The 3 Most Promising Stocks Worth Gambling On ...
# 3      2024-07-01     GM  Vroom! 3 EV Stocks With the Potential to Outru...
# 4      2024-07-01    HAL  Black Gold Bargains: 7 Discounted Oil Stocks R...
# ...           ...    ...                                                ...
# 54670  2024-07-26    CCL  Pool Corp (POOL) Q2 Earnings &amp; Revenues To...
# 54671  2024-07-26   POOL  Pool Corp (POOL) Q2 Earnings &amp; Revenues To...
# 54672  2024-07-26   TEAM  Atlassian (TEAM) to Report Q4 Earnings: What's...
# 54673  2024-07-26    EME  EMCOR (EME) Q2 Earnings &amp; Revenues Beat Es...
# 54674  2024-07-26   CTSH  CommVault (CVLT) to Report Q1 Earnings: What's...
#
# ...

# %%
# Check for 'Amazon' in 'Headline' column (case-insensitive)
headline_count = extracted_data['Headline'].str.contains('Amazon', case=False, na=False).sum()
print(f"Records with 'Amazon' in Headline column: {headline_count}")

# Check for 'Amazon' in 'title' column (case-insensitive)
title_count = extracted_data['title'].str.contains('Amazon', case=False, na=False).sum()
print(f"Records with 'Amazon' in title column: {title_count}")

# Optional: View the actual records
print("\n--- Records with 'Amazon' in Headline ---")
print(extracted_data[extracted_data['Headline'].str.contains('Amazon', case=False, na=False)])

print("\n--- Records with 'Amazon' in title ---")
print(extracted_data[extracted_data['title'].str.contains('Amazon', case=False, na=False)])
# Out:
# Records with 'Amazon' in Headline column: 38309
# Records with 'Amazon' in title column: 235
#
# --- Records with 'Amazon' in Headline ---
#          date_day Ticker                                              title  \
# 0      2024-07-01    BDX  Boing! 7 Undervalued Stocks That Could Surpris...
# 2      2024-07-01    EME  The 3 Most Promising Stocks Worth Gambling On ...
# 3      2024-07-01     GM  Vroom! 3 EV Stocks With the Potential to Outru...
# 4      2024-07-01    HAL  Black Gold Bargains: 7 Discounted Oil Stocks R...
# 6      2024-07-01   JOBY  7 Dirt-Cheap Stocks Under $10 With Explosive U...
# ...           ...    ...                                                ...
# 54668  2024-07-26   PAYC  Is a Beat in Store for Paycom (PAYC) This Earn...
# 54670  2024-07-26    CCL  Pool Corp (POOL) Q2 Earnings &amp; Revenues To...
# 54671  2024-07-26   POOL  Pool Corp (POOL) Q2 Earnings &amp; Revenues To...
# ...
